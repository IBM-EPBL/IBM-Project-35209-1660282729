# %%
from keras.models import load_model
import matplotlib.pyplot as plt

# %%
model = load_model("CNN_mnist.h5")
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Image.open(r"C:\Users\SUKUMAR\OneDrive\Desktop\sample\samples6.png")
plt.imshow(img)

# %%
img = Image.open(r"C:\Users\SUKUMAR\OneDrive\Desktop\sample\samples8.png")
plt.imshow(img)

# %%
img = Image.open(r"C:\Users\SUKUMAR\OneDrive\Desktop\sample\samples2.png")
plt.imshow(img)

# %%
img = Image.open(r"C:\Users\SUKUMAR\OneDrive\Desktop\sample\samples10.png")
plt.imshow(img)

# %%
for index in range(1,5):
    img = Image.open(r"C:\Users\SUKUMAR\OneDrive\Desktop\sample\samples" +str(index)+'.png').convert("L")
    img = img.resize((28,28))
    img2arr = np.array(img)
    img2arr = img2arr.reshape(1,28,28,1)
    y_pred = model.predict(img2arr)
    print(y_pred)
    print(f"The image_{index} predicted as value {np.argmax(y_pred)}")
# Out:
# 1/1 [==============================] - 0s 38ms/step
# [[8.6461940e-09 4.2855218e-02 4.5102973e-02 4.3741971e-01 4.9977031e-02
#   2.3294676e-07 7.7207835e-04 1.5294469e-11 6.7416288e-02 1.3920483e-23
#   1.4947538e-02 6.2255068e-03 4.6485174e-03 4.0966511e-02 3.0194123e-03
#   1.1478143e-02 1.6200814e-02 2.4020486e-02 2.2461233e-01 1.0337124e-02]]
# The image_1 predicted as value 3
# 1/1 [==============================] - 0s 44ms/step
# [[9.61004794e-01 1.21646935e-05 6.30360702e-03 3.34337713e-08
#   3.23088170e-06 5.67461529e-06 3.26704383e-02 2.35403995e-29
#   3.51927412e-08 1.64892755e-09 3.48763797e-13 2.06930798e-16
#   2.42134469e-15 6.81922238e-13 9.37051112e-08 1.23114227e-16
#   2.01665919e-12 4.39071143e-13 7.21634070e-13 1.90006277e-09]]
# The image_2 predicted as value 0
# 1/1 [==============================] - 0s 39ms/step
# [[0.0000000e+00 1.5126494e-19 2.0510791e-21 9.9989760e-01 1.9028487e-32
#   9.9484401e-05 0.0000000e+00 5.3212253e-23 1.4659159e-17 2.9541004e-06
# ...
